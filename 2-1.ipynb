# %%
import pandas as pd

df = pd.read_csv('data/Fish.csv')

# %%
cond =  df['Species'].isin(['Bream', 'Smelt'])
df.loc[cond]
lw_df = df.loc[cond, ['Length2', 'Weight']]
fish_data = lw_df.values.tolist()

# %%
fish_target = [1] * 35 + [0] * 14

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
train_input = fish_data[:35]
train_target = fish_target[:35]

test_input = fish_data[35:]
test_target = fish_target[35:]

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 0.0

# %%
import numpy as np

# %%
input_arr = np.array(fish_data)
target_arr = np.array(fish_target)

# %%
np.random.seed(42)
index =np.arange(49)
np.random.shuffle(indeㅑㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏx)
print(index)
# Out:
# [13 45 47 44 17 27 26 25 31 19 12  4 34  8  3  6 40 41 46 15  9 16 24 33
#  30  0 43 32  5 29 11 36  1 21  2 37 35 23 39 10 22 18 48 20  7 42 14 28
#  38]

# %%
input_arr[[1, 3]]
# Out:
# array([[ 26.3, 290. ],
#        [ 29. , 363. ]])

# %%
test_input = input_arr[index[35:]]
test_target = target_arr[index[35:]]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(train_input[:,0], train_input[:, 1])
plt.scatter(test_input[:,0], test_input[:,1])

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
kn.predict(test_input)
# Out:
# array([0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 1, 1, 0])

# %% [markdown]
# ## iris

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

# setosa, versicolor 종분류
iris
# petal_Length, petal_width 특성기준으로
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
cond =  iris['species'].isin(['setosa', 'versicolor'])
iris.loc[cond]
sv_iris = iris.loc[cond, ['petal_length', 'petal_width']]
flower_data = sv_iris.values.tolist()

# %%
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
flower_target = [0] * 50 + [1] * 50

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
train_input = flower_data[:50]
train_target = flower_target[:50]

test_input = flower_data[50:]
test_target = flower_target[50:]

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 0.0

# %%
import numpy as np

# %%
input_arr = np.array(flower_data)
target_arr = np.array(flower_data)

# %%
np.random.seed(50)
index = np.arange(50)
np.random.shuffle(index)
print(index)
# Out:
# [34 36  1 38  8 16 35 13 29 24 18 46 12 23 25  3 39 15 41 19 49  0  9 10
#  21 17 47 20 40 44 26 27 28 14 43  7 31  2  5 22 42 37  6  4 30 33 45 11
#  32 48]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
input_arr = np.array(flower_data)
target_arr = np.array(flower_data)

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 0.0

# %%
input_arr[[1, 3]]
# Out:
# array([[1.4, 0.2],
#        [1.5, 0.2]])

# %%
train_input = input_arr[index[:50]]
train_target = target_arr[index[:50]]

test_input = input_arr[index[50:]]
test_target = target_arr[index[50:]]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(train_input[:,0], train_input[:, 1])
plt.scatter(test_input[:,0], test_input[:,1])

# %%
setosa_iris = iris.loc[iris['species'] == 'setosa']

setosa_length = setosa_iris['petal_length'].tolist()
setosa_weight = setosa_iris['petal_width'].tolist()

# %%
versicolor_iris = iris.loc[iris['species']== 'versicolor']

versicolor_length = versicolor_iris['petal_length'].tolist()
versicolor_weight = versicolor_iris['petal_width'].tolist()

# %%
plt.scatter(setosa_length, setosa_weight)
plt.scatter(versicolor_length, versicolor_weight)

# %% [markdown]
# ## 샘풀이

# %%
cond = iris['species'].isin(['setos', 'versicolor'])
iris_df = iris.loc[cond, ['petal_length', 'petal_width']]

iris_data = iris_df.values

# %%
import numpy as np
iris_target =[1] * 50 + [2] * 50

# %%
import random
index = list(range(0,100))
random.shuffle(index)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 train_input = iris_data[index[:70]]
#       2 train_target = iris_target[index[:70]]
#
# IndexError: index 72 is out of bounds for axis 0 with size 50
