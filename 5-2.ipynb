# %% [markdown]
# ## 검증세트
# - 우리의 목표
# train, test 점수를 높인다! 과대적합이 뭐지? test에 너무 몰입하는거 아냐? 학습용과 테스트를 75:25로 나누는테 너무 테스트에만 몰입하는 모델나오겠는데 이것을 검증~

# %%
import pandas as pd

wine = pd.read_csv('http://bit.ly/wine_csv_data')
wine.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
data = wine[['alcohol','sugar', 'pH']]
target = wine[['class']]

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = \
train_test_split(data, target)

# %%
sub_input, val_input, sub_target, val_target = \
train_test_split(train_input, train_target)

# %%
sub_input.shape
#val_input.shape
#test_input.shape
# Out:
# (3654, 3)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(sub_input, sub_target)
print(dt.score(sub_input, sub_target))
print(dt.score(val_input, val_target))
# Out:
# 0.9980842911877394
# 0.8596059113300493

# %%
print(dt.score(test_input, test_target))
# Out:
# 0.8621538461538462

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(dt, train_input, train_target)
print(scores)
# Out:
# {'fit_time': array([0.0089469 , 0.00737309, 0.00739813, 0.00797606, 0.00779223]), 'score_time': array([0.00231814, 0.00217009, 0.00280285, 0.00176287, 0.00180507]), 'test_score': array([0.8574359 , 0.85333333, 0.86652977, 0.86755647, 0.85010267])}

# %% [markdown]
# ## 그리드서치

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'min_impurity_decrease':[0.0001, 0.0002, 0.0003, 0.0004]
}

# %%
gs = GridSearchCV(dt, params, n_jobs=-1)

# %%
gs.fit(train_input, train_target)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'min_impurity_decrease': [0.0001, 0.0002, 0.0003,
#                                                    0.0004]})

# %%
gs.best_estimator_
# Out:
# DecisionTreeClassifier(min_impurity_decrease=0.0002)
