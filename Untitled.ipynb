# %% [markdown]
# ## Penguins
# - Adelie, Gentoo 구분하기.

# %%
import seaborn as sns

df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
cond = df['species'].isin(['Adelie', 'Gentoo'])
penguin_data = df.loc[cond, ['bill_length_mm', 'body_mass_g']]
penguin_target = df.loc[cond, ['species']]

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(penguin_data, penguin_target)

# %%
np.random.seed(30)
index = np.arange(30)
np.random.shuffle(index)
print(index)
# Out:
# [15 28 26 10 24  0  8  6 25  4 11 22 18 19  1 16  7  9  3 14 17 21  2 23
#  12 20 27 13 29  5]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
import numpy as np
input_arr = np.array(penguin_data)
target_arr = np.array(penguin_data)

# %%
train_input = input_arr[index[:30]]
train_target = target_arr[index[:30]]

test_input = input_arr[index[30:]]
test_target = target_arr[index[30:]]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(train_input[:,0], train_input[:, 1])
plt.scatter(test_input[:,0], test_input[:,1])

# %%
import matplotlib.pyplot as plt

species_list = df['species'].unique()


for species, color in zip(species_list, colors):
    species_data = df[df['species'] == species]
    plt.scatter(species_data['bill_length_mm'], species_data['body_mass_g'])

plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df['bill_length_mm'] = df['bill_length_mm'].fillna(df['bill_length_mm'].mean())
df['bill_depth_mm'] = df['bill_depth_mm'].fillna(df['bill_depth_mm'].mean())
df['flipper_length_mm'] = df['flipper_length_mm'].fillna(df['flipper_length_mm'].mean())
df['body_mass_g'] = df['body_mass_g'].fillna(df['body_mass_g'].mean())

# %%
cond = df['species'].isin(['Adelie', 'Gentoo'])
penguin_data = df.loc[cond, ['bill_length_mm', 'body_mass_g']]

# %%
penguin_target = df.loc[cond, ['species']]
from sklearn.model_selection import train_test_split

# %%
train_input, test_input, train_target, test_target = train_test_split(penguin_data, penguin_target)

# %%
df.notnull().sum()
# Out:
# species              344
# island               344
# bill_length_mm       344
# bill_depth_mm        344
# flipper_length_mm    344
# body_mass_g          344
# sex                  333
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

kn = KNeighborsClassifier()

kn.fit(train_input, train_target['species'])
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target['species'])
# Out:
# 0.855072463768116

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input['bill_length_mm'], train_input['body_mass_g'])
